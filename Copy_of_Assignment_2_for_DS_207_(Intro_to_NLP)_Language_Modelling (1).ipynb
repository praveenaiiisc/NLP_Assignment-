# %% [markdown]
# # Assignment 2: Language Modelling (TA: Navreet Kaur)
#
# The goal of this assignment is to model Indian first names using character-level language models.
#
# You'll have to add your code wherever you see the comment `# ADD YOUR CODE HERE`. Please make a copy of this assignment, and you can use Google Colab notebooks to work on this. Later, you can download this notebook as a python file and submit it as per the following instructions.
#
# **Important Note**: Whenever you add your code, please enclose your code block within two comments `# BEGIN CODE` and `# END CODE` to indicate the start and end of your code.
# Example:
#
# ```
# def model():
#
#     data = get_dataloader() # this is defined by us
#
#     # ADD YOUR CODE HERE
#
#     # BEGIN CODE
#
#     run_training() # this is written by you
#
#     generate_names() # this is written by you
#
#     # END CODE
#
# ```

# %% [markdown]
# ## Submission Instructions

# %% [markdown]
# Note that your assignment will be based on the results obtained by functions implemented by you. Do not change the print statements having `EVALUATION` as they are used for auto-evaluation.
#
# You'd need to submit the following files:
#
#   * Save this `.ipynb` to your drive, complete the required code blocks and run the notebook.
#
#   * After completing this assignment, download the notebook as`.py`. Name it as `SAPname_SRno_assignment2.py`, where `SAPname` refers to your name as per SAP record, and `SRno` refers to the last 5 digits of your IISc SR number. For example, IISc student with SAP name Twyla Linda (SR no - 04-03-00-10-22-20-1-15329) would name it as `Twyla_Linda_15329_assignment2.py`.
#
#   *   The files associated with FNN and RNN models i.e. `model.pt`, `vocab.pt` and `loss.json` will be downloaded and saved in folders with names `fnn` and `rnn` respectively, and these will be contained within folder `SAPname_SRno`. Zip this folder along with the `.py` file, save it as `SAPname_SRno_assigment2` and upload on MS Teams. The directory can be summarised as follows:
#
# ```
# SAPname_SRno_assigment2
# │   SAPname_SRno_assignment2.py
# │
# └───SAPname_SRno
# │   │
# │   └───fnn
# │   │   │   model.pt
# │   │   │   vocab.pt
# │   │   │   loss.json
# │   │
# │   └───rnn
# │       │   model.pt
# │       │   vocab.pt
# │       │   loss.json
#
# ```
#
# Because submissions are auto-graded, please ensure that the naming of the files is consistent with the instructions.

# %% [markdown]
# ## Broad Outline
#
# In this assignment, we will implement different types of language models for modeling Indian names. There are clealry patterns in Indian names that models could learn, and we start modeling those using n-gram models, then move to neural n-gram and RNN models.
#
#
# **Marks Distribution:**
# - Unigram: 5
# - Bigram: 15
# - Trigram: 10
# - Neural N-gram LM: 30
# - RNN LM: 40

# %% [markdown]
# # Read and Preprocess Data

# %%
# importing necessary libraries
import pandas as pd
import numpy as np
import math

import random
from collections import Counter, defaultdict

from torchtext.vocab import build_vocab_from_iterator
from torch.utils.data import DataLoader

# %% [markdown]
# Please note that we may change the contents of the following four files when we rerun your code, so please make sure that your solution is not specifically engineered to just these names.

# %%
# Download the training and validation datasets
# !wget -O train_data.csv "https://docs.google.com/spreadsheets/d/1AUzwOQQbAehg_eoAMCcWfwSGhKwSAtnIzapt2wbv0Zs/gviz/tq?tqx=out:csv&sheet=train_data.csv"
# !wget -O valid_data.csv "https://docs.google.com/spreadsheets/d/1UtQErvMS-vcQEwjZIjLFnDXlRZPxgO1CU3PF-JYQKvA/gviz/tq?tqx=out:csv&sheet=valid_data.csv"

# Download the text for evaluation
# !wget -O eval_prefixes.txt "https://drive.google.com/uc?export=download&id=1tuRLJXLd2VcDaWENr8JTZMcjFlwyRo60"
# !wget -O eval_sequences.txt "https://drive.google.com/uc?export=download&id=1kjPAR04UTKmdtV-FJ9SmDlotkt-IKM3b"
# Out:
# --2024-02-23 15:27:46--  https://docs.google.com/spreadsheets/d/1AUzwOQQbAehg_eoAMCcWfwSGhKwSAtnIzapt2wbv0Zs/gviz/tq?tqx=out:csv&sheet=train_data.csv
# Resolving docs.google.com (docs.google.com)... 172.217.212.113, 172.217.212.139, 172.217.212.138, ...
# Connecting to docs.google.com (docs.google.com)|172.217.212.113|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/csv]
# Saving to: ‘train_data.csv’
#
# train_data.csv          [ <=>                ]  71.07K  --.-KB/s    in 0.01s
#
# 2024-02-23 15:27:47 (5.24 MB/s) - ‘train_data.csv’ saved [72776]
#
# --2024-02-23 15:27:47--  https://docs.google.com/spreadsheets/d/1UtQErvMS-vcQEwjZIjLFnDXlRZPxgO1CU3PF-JYQKvA/gviz/tq?tqx=out:csv&sheet=valid_data.csv
# Resolving docs.google.com (docs.google.com)... 172.217.212.113, 172.217.212.139, 172.217.212.138, ...
# Connecting to docs.google.com (docs.google.com)|172.217.212.113|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/csv]
# Saving to: ‘valid_data.csv’
#
# valid_data.csv          [ <=>                ]  19.76K  --.-KB/s    in 0s
#
# 2024-02-23 15:27:47 (66.5 MB/s) - ‘valid_data.csv’ saved [20230]
#
# --2024-02-23 15:27:47--  https://drive.google.com/uc?export=download&id=1tuRLJXLd2VcDaWENr8JTZMcjFlwyRo60
# Resolving drive.google.com (drive.google.com)... 209.85.200.139, 209.85.200.113, 209.85.200.101, ...
# Connecting to drive.google.com (drive.google.com)|209.85.200.139|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1tuRLJXLd2VcDaWENr8JTZMcjFlwyRo60&export=download [following]
# --2024-02-23 15:27:47--  https://drive.usercontent.google.com/download?id=1tuRLJXLd2VcDaWENr8JTZMcjFlwyRo60&export=download
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 173.194.74.132, 2607:f8b0:4001:c0d::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|173.194.74.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12 [application/octet-stream]
# Saving to: ‘eval_prefixes.txt’
#
# eval_prefixes.txt   100%[===================>]      12  --.-KB/s    in 0s
#
# 2024-02-23 15:27:47 (538 KB/s) - ‘eval_prefixes.txt’ saved [12/12]
#
# --2024-02-23 15:27:48--  https://drive.google.com/uc?export=download&id=1kjPAR04UTKmdtV-FJ9SmDlotkt-IKM3b
# Resolving drive.google.com (drive.google.com)... 209.85.200.139, 209.85.200.113, 209.85.200.101, ...
# Connecting to drive.google.com (drive.google.com)|209.85.200.139|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1kjPAR04UTKmdtV-FJ9SmDlotkt-IKM3b&export=download [following]
# --2024-02-23 15:27:48--  https://drive.usercontent.google.com/download?id=1kjPAR04UTKmdtV-FJ9SmDlotkt-IKM3b&export=download
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 173.194.74.132, 2607:f8b0:4001:c0d::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|173.194.74.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12 [application/octet-stream]
# Saving to: ‘eval_sequences.txt’
#
# eval_sequences.txt  100%[===================>]      12  --.-KB/s    in 0s
#
# 2024-02-23 15:27:48 (601 KB/s) - ‘eval_sequences.txt’ saved [12/12]

# %%
## Please do not change anything in this code block.

def read_dataframe(ds_type):
    """
    Args:
        ds_type [str] :  dataset type (train or valid)

    Returns:
        df [pandas dataframe]
    """

    df = pd.read_csv(f"/content/{ds_type}_data.csv", header=0, index_col=0)
    df = df[~df['Name'].isna()]
    df['Name'] = df['Name'].astype(str)
    return df

# Load the training and validation datasets
train_data = read_dataframe("train")
validation_data = read_dataframe("valid")

# Read files containing prefixes and character sequences for evaluation
with open('eval_prefixes.txt', 'r') as file:
    eval_prefixes = []
    for line in file:
        eval_prefixes.append(line.strip().split(" "))

with open('eval_sequences.txt', 'r') as file:
    eval_sequences = []
    for line in file:
        eval_sequences.append(line.strip().split(" "))

print(f"Length of training data: {len(train_data)}\nLength of validation data: {len(validation_data)}")
# Out:
# Length of training data: 4539
# Length of validation data: 1297

# %%
## Please do not change anything in this code block.

START = "<s>"   # Start-of-name token
END = "</s>"    # End-of-name token
UNK = "<unk>"   # token representing out of unknown (or out of vocabulary) tokens
vocab_from_ascii = True

def build_vocab(names):
    """
    Builds a vocabulary given a list of names

    Args:
        names [list[str]]: list of names

    Returns:
        vocab [torchtext.vocab]: vocabulary based on the names

    """

    if vocab_from_ascii:
        char_counts = {chr(i):i for i in range(97,123)}
    else:
        char_counts = Counter("".join(names))

    vocab = build_vocab_from_iterator(
                    char_counts,
                    specials=[UNK, START, END], #adding special tokens to the vocabulary
                    min_freq=1
                )
    vocab.set_default_index(vocab[UNK])
    return vocab


def tokenize_name(name):
    """
    Tokenise the name i.e. break a name into list of characters

    Args:
        name [str]: name to be tokenized

    Returns:
        list of characters
    """

    return list(str(name))


def process_data_for_input(data_iter, vocab):
    """
    Processes data for input: Breaks names into characters,
    converts out of vocabulary tokens to UNK and
    appends END token at the end of every name

    Args:
        data_iter: data iterator consisting of names
        vocab: vocabulary

    Returns:
        data_iter [list[list[str]]]: list of names, where each name is a
                                list of characters and is appended with
                                START and END tokens

    """

    vocab_set = set(vocab.get_itos())
    # convert Out Of Vocabulary (OOV) tokens to UNK tokens
    data_iter = [[char if char in vocab_set else UNK
                        for char in tokenize_name(name)] for name in data_iter]
    data_iter = [[START] + name + [END] for name in data_iter]

    return data_iter


def get_tokenised_text_and_vocab(ds_type, vocab=None):
    """
    Reads input data, tokenizes it, builds vocabulary (if unspecified)
    and outputs tokenised list of names (which in turn is a list of characters)

    Args:
        ds_type [str]: Type of the dataset (e.g., train, validation, test)
        vocab [torchtext.vocab]: vocabulary;
                                 If vocab is None, the function will
                                 build the vocabulary from input text.
                                 If vocab is provided, it will tokenize name
                                 according to the vocab, replacing any tokens
                                 not part of the vocab with UNK token.

    Returns:
        data_iter: data iterator for tokenized names
        vocab: vocabulary

    """

    # read the 'Name' column of the dataframe
    if ds_type=='train':
        data_iter = train_data['Name']
    elif ds_type=='valid':
        data_iter = validation_data['Name']
    else:
        data_iter = test_data['Name']

    # build vocab from input data, if vocab is unspecified
    if vocab is None:
        vocab = build_vocab(data_iter)

    # convert OOV chars to UNK, append START and END token to each name
    data_iter = process_data_for_input(data_iter, vocab)

    return data_iter, vocab

# %% [markdown]
# Let's look at some examples from the training set

# %%
# Look at some random examples from the training set
examples = ", ".join(random.sample(list(train_data['Name']), 5))
f"Examples from the training set: {examples}"
# Out:
# 'Examples from the training set: saku, guljar, satender, asif, mana'

# %% [markdown]
# # Module 1: N-gram Language Modelling

# %% [markdown]
# Load and preprocess the data for n-gram models

# %%
"""choose your hyperparameter and see the difference in performance"""

# CHANGE THE None VALUES TO YOUR DESIRED VALUES

# ADD YOUR CODE HERE

MAX_NAME_LENGTH = 8 # maximum length of names for generation

# %%
# Get data iterator and build vocabulary from input text

train_text, vocab = get_tokenised_text_and_vocab(ds_type='train')
validation_text, _ = get_tokenised_text_and_vocab(ds_type='valid', vocab=vocab)

# Check the size of vocabulary
vocab_size = len(vocab.get_stoi())
print(vocab_size)
# Out:
# 29

# %% [markdown]
# Now it's time to implement an [n-gram language model](https://web.stanford.edu/~jurafsky/slp3/3.pdf).
#
# One edge case you will need to handle is that you don't have $n-1$ prior characters at the beginning of the text.  One way to do this is by appending the `START` token $n-1$ times at the start of the name, when implementing an $n$-gram model. You may choose whichever method you like to handle this case as long as you produce a valid probability distribution (one that sums to one).
#
# **Generating names**
#
# To generate from a language model, we can sample one char at a time conditioning on the chars we have generated so far.
#
# In fact there are many strategies to get better-sounding samples, such as only sampling from the top-k chars or sharpening the distribution with a temperature.  You can read more about sampling from a language model in [this](https://arxiv.org/pdf/1904.09751.pdf) paper.
#
#
# We will now implement N-gram models with $N=1$ (unigram), $N=2$ (bigram), and $N=3$ (trigram).
#
# **Utility Functions**
#
# Implement the utility functions `get_unigram_counts`, `get_bigram_counts` and `get_trigram_counts`. You can use these functions while implementing n-gram models.

# %%
def get_unigram_counts(corpus):
    """
    Given a corpus, calculates the unigram counts for each character in the corpus

    Args:
        corpus [list[list[str]]]: list of tokenized characters. Text is appended with END token.

    Returns:
        unigram_counts [dict [key: char, value: count]]:
            dictionary of unigram counts for each character in the corpus
        Example:
        > unigram_counts["c1"] = 5
    """

    # ADD YOUR CODE HERE
    # START CODE
    unigram_counts = {}
    for name in corpus:
      for char in name:
        if char == '<s>' :  # Include '</s> to get good perplexity doubt missed e+16
          continue
        unigram_counts[char] = unigram_counts.get(char, 0) + 1
    # END CODE

    return unigram_counts

# %%
def get_bigram_counts(corpus):
    """
    Given a corpus, calculates the bigram counts for each bigram in the corpus.
    The corpus *only* contains END tokens at the end of names.
    You may want to handle the case whhere beginning of the name
    does not have n-1 prior chars.

    Args:
        corpus [list[list[str]]]: list of tokenized text. Text is appended with END token.

    Returns:
        bigram_counts [dict[dict]]:
            nested dictionary of bigram counts for each bigram in the corpus
        Example:
        > bigram_counts["c1"]["c2"] = 5
        here bigram_counts["c1"]["c2"] represents P("c2"|"c1")
        P["c1"]["c2"] means P[char_i = "c2"|char_{i-1} = "c1"]
    """

    # ADD YOUR CODE HERE
    # START CODE
    bigram_counts = {}
    for name in corpus:
      for i in range(len(name)):
        char2 = name[i]
        if char2 == '<s>':
          continue
        if i!=0:
          char1 = name[i - 1]
        else:
          char1 = '<s>'

        if char1 not in bigram_counts:
          bigram_counts[char1] = {}

        bigram_counts[char1][char2] = bigram_counts[char1].get(char2, 0) + 1
    # END CODE

    return bigram_counts

# %%
def get_trigram_counts(corpus):
    """
    Given a corpus, calculates the trigram counts for each trigram in the corpus.
    The corpus *only* contains END tokens at the end of names.
    You may want to handle the case where beginning of the text
    does not have n-1 prior chars.

    Args:
        corpus [list[list[str]]]: list of tokenized text. Text is appended with END token.

    Returns:
        trigram_counts [dict[dict[dict]]]:
            nested dictionary for each trigram in the corpus
        Example:
        > trigram_counts["c1"]["c2"]["c3"] = 5
        P["c1"]["c2"]["c3] means P[char_i = "c3"|char_{i-2} = "c1", char_{i-1} = "c2"]

    """

    # ADD YOUR CODE HERE
    # START CODE
    trigram_counts = {}
    for name in corpus:
      for i in range(len(name)):
        char3 = name[i]
        if char3 == '<s>' :
          continue
        if i==0:
          char1 = '<s>'
          char2 = '<s>'
        elif i==1:
          char1 = '<s>'
          char2 = name[i - 1]
        else:
          char1 = name[i - 2]
          char2 = name[i - 1]
        if char1 not in trigram_counts:
          trigram_counts[char1] = {}
        if char2 not in trigram_counts[char1]:
          trigram_counts[char1][char2] = {}

        trigram_counts[char1][char2][char3] = trigram_counts[char1][char2].get(char3, 0) + 1

    # END CODE

    return trigram_counts

# %%
"""
Implementation of the n-gram language models.
All other n-gram models (unigram, bigram, etc.) would follow the same skeleton.
"""

class NGramLanguageModel(object):
    def __init__(self, train_text):
        """
        Initialise and train the model with train_text.

        Args:
            train_text [list of list]: list of tokenised names

        Returns:
            -
        """
        return

    def get_next_char_probabilities(self):
        """
        Returns a probability distribution over all chars in the vocabulary.
        Probability distribution should sum to one.

        Returns:
            P: dictionary or nested dictionary; Output format depends on n-gram
            Examples:
                for N=1 (unigram); dict[key:unigram,value:probability of unigram]
                    > P["c1"] = 0.0001
                for N=2 (bigram); dict[key:bigram_char1, value:dict[key:bigram_char2,value:probability of bigram]]
                    > P["c1"]["c2"] = 0.0001
                    P["c1"]["c2"] means P["c2"|"c1"]
                for N=3 (trigram); dict[dict[dict]]
                    > P["c1"]["c2"]["c3"] = 0.0001
                    P["c1"]["c2"]["c3] means P[char_i = "c3"|char_{i-2} = "c1", char_{i-1} = "c2"]
        """

        return


    def get_name_log_probability(self, name):
        """
        Calculates the log probability of name according to the language model

        Args:
            name [list]: list of tokens

        Returns:
            log_prob [float]: Log probability of the given name
        """
        return 0.0


    def get_perplexity(self, text):
        """
        Returns the perplexity of the model on a text as a float.

        Args:
            text [list]: a list of string tokens

        Returns:
            perplexity [float]: perplexity of the given text
        """
        return 0.0


    def generate_names(self, k, n=MAX_NAME_LENGTH, prefix=None):
        """
        Given a prefix, generate k names according to the model.
        The default prefix is None.
        You may stop the generation when n tokens have been generated,
        or when you encounter the END token.

        Args:
            k [int]: Number of names to generate
            n [int]: Maximum length (number of tokens) in the generated name
            prefix [list of tokens]: Prefix after which the names have to be generated

        Returns:
            names [list[str]]: list of generated names
        """
        return []

    def get_most_likely_chars(self, sequence, k):
        """
        Given a sequence of characters, outputs k most likely characters after the sequence.

        Args:
            sequence [list[str]]: list of characters
            k [int]: number of most likely characters to return

        Returns:
            chars [list[str]]: *Ordered* list of most likely characters
                        (with charcater at index 0 being the most likely and
                        character at index k-1 being the least likely)

        """
        return []

# %%
## Please do not change anything in this code block.

def check_validity(model, ngram, is_neural):
    """
    Checks if get_next_char_probabilities returns a valid probability distribution
    """

    if ngram==1 or is_neural:
        P = model.get_next_char_probabilities()
        is_valid = validate_probability_distribution(P.values())
        if not is_valid:
            return is_valid

    elif ngram==2:
        P = model.get_next_char_probabilities()
        for char1 in P.keys():
            is_valid = validate_probability_distribution(list(P[char1].values()))
            if not is_valid:
                return is_valid

    elif ngram==3:
        P = model.get_next_char_probabilities()
        for char1 in P.keys():
            for char2 in P[char1].keys():
                is_valid = validate_probability_distribution(list(P[char1][char2].values()))
                if not is_valid:
                    return is_valid
    else:
        print("Enter a valid number for ngram")

    return True


def validate_probability_distribution(probs):
    """
    Checks if probs is a valid probability distribution
    """
    if not min(probs) >= 0:
        print("Negative value in probabilities")
        return False
    elif not max(probs) <= 1 + 1e-8:
        print("Value larger than 1 in probabilities")
        return False
    elif not abs(sum(probs)-1) < 1e-4:
        print("probabilities do not sum to 1")
        return False
    return True


def eval_ngram_model(model, ngram, ds, ds_name, eval_prefixes, eval_sequences, num_names=5, is_neural=False):
    """
    Runs the following evaluations on n-gram models:
    (1) checks if probability distribution returned by model.get_next_char_probabilities() sums to one
    (2) checks the perplexity of the model
    (3) generates names using model.generate_names()
    (4) generates names given a prefix using model.generate_names()
    (4) output most likely characters after a given sequence of chars using model.get_most_likely_chars()
    """

    # (1) checks if probability distributions sum to one
    is_valid = check_validity(model=model, ngram=ngram, is_neural=is_neural)
    print(f'EVALUATION probability distribution is valid: {is_valid}')

    # (2) evaluate the perplexity of the model on the dataset
    print(f'EVALUATION of {ngram}-gram on {ds_name} perplexity:',
        model.get_perplexity(ds))

    # (3) generate a few names
    generated_names = ", ".join(model.generate_names(k=num_names))
    print(f'EVALUATION {ngram}-gram generated names are {generated_names}')

    # (4) generate a few names given a prefix
    for prefix in eval_prefixes:
        generated_names_with_prefix = ", ".join(model.generate_names(k=num_names, prefix=prefix))
        prefix = ''.join(prefix)
        print(f'EVALUATION {ngram}-gram generated names with prefix {prefix} are {generated_names_with_prefix}')

    # (5) get most likely characters after a sequence
    for sequence in eval_sequences:
        most_likely_chars = ", ".join(model.get_most_likely_chars(sequence=sequence, k=num_names))
        sequence = "".join(sequence)
        print(f"EVALUATION {ngram}-gram top most likely chars after {sequence} are {most_likely_chars}")

# %% [markdown]
# The perplexity changes with inclusion of </s> in counts I have not included it for now, but if included try to  not use p('</s>'/word) in perplexity calculation

# %% [markdown]
# ## 1.1 Unigram

# %%
"""
Implementaion of a Unigram Model without smoothing
"""

class UnigramModel(NGramLanguageModel):
    def __init__(self, train_text):
        """
        Initialise and train the model with train_text.

        Args:
            train_text [list of list]: list of tokenised names
        """

        # ADD YOUR CODE HERE
        # START CODE
        super(UnigramModel, self).__init__(train_text)
        self.unigram_counts = get_unigram_counts(train_text)
        #print(self.unigram_counts)
        self.total_tokens = sum(self.unigram_counts.values())
        self.vocab = vocab
        self.vocab_size = vocab_size
        self.next_char_probabilities = self.get_next_char_probabilities()
        # END CODE


    def get_next_char_probabilities(self):
        """
        Return a dictionary of probabilities for each char in the vocabulary

        Returns:
            key: char, value: probability
        """

        # ADD YOUR CODE HERE
        # START CODE
        next_char_probabilities = {}
        vocab_set = self.vocab.get_itos()
        for char in vocab_set:
          next_char_probabilities[char] = (self.unigram_counts.get(char, 0)) / self.total_tokens
        # END CODE
        #print(next_char_probabilities['</s>'])
        return next_char_probabilities



    def get_name_log_probability(self, name):
        """
        Calculates the log probability of name according to the n-gram model

        Args:
            name [list]: list of tokens

        Returns:
            Log probability of the name [float]
        """

        # ADD YOUR CODE HERE
        # START CODE
        name_log_probability = 0.0
        for char in name:
          if char=="<s>" or char == "</s>":
            continue
          if char in self.next_char_probabilities:  #and self.next_char_probabilities[char]!=0.0
            char_probability = self.next_char_probabilities[char]
          else:
            char_probability = self.next_char_probabilities["<unk>"]
          if char_probability==0:
              return float('-inf')
          name_log_probability += math.log(char_probability)

        # END CODE

        return name_log_probability



    def get_perplexity(self, text):
        """
        Returns the perplexity of the model on a text as a float.

        Args:
            text [list]: a list of string tokens

        Returns:
            perplexity of the given text [float]
        """

        # ADD YOUR CODE HERE
        # START CODE
        count = 0
        for name in text:
          count += len(name)-1  # Not including start word
        total_log_probability = sum(self.get_name_log_probability(name) for name in text)
        avg_log_probability = total_log_probability / count
        perplexity = math.exp(-avg_log_probability)

        # END CODE

        return perplexity


    def generate_names(self, k, n=MAX_NAME_LENGTH, prefix=None):
        """
        Given a prefix, generate k names according to the model.
        The default prefix is None.

        Args:
            k [int]: Number of names to generate
            n [int]: Maximum length (number of tokens) in the generated name
            prefix [list of tokens]: Prefix after which the names have to be generated

        Returns:
            list of generated names [list]
        """

        # ADD YOUR CODE HERE
        # START CODE
        filtered_probabilities = {char: prob for char, prob in self.next_char_probabilities.items() if char not in {"<unk>", "<s>"}}
        names = []
        for i in range(k):
          if prefix == None:
            temp_name = []
          else:
            temp_name = list(prefix)
          for j in range(n):
            char = random.choices(list(filtered_probabilities.keys()), weights=list(filtered_probabilities.values()))[0]
            if char=='</s>':
              break
            temp_name.append(char)
          temp_name = ''.join(temp_name)
          names.append(temp_name)
        # END CODE


        return names


    def get_most_likely_chars(self, sequence, k):
        """
        Given a sequence of characters, outputs k most likely characters after the sequence.

        Args:
            sequence [list[str]]: list of characters
            k [int]: number of most likely characters to return

        Returns:
            chars [list[str]]: *Ordered* list of most likely characters
                        (with charcater at index 0 being the most likely and
                        character at index k-1 being the least likely)

        """
        # ADD YOUR CODE HERE
        # START CODE
        sorted_chars = sorted(self.next_char_probabilities.keys(), key=lambda char: self.next_char_probabilities[char], reverse=True)
        most_likely_chars = sorted_chars[:k]
        # END CODE

        return most_likely_chars

# %% [markdown]
# ### Eval

# %% [markdown]
# **Note**: For models without smoothing, you may observe perplexity as `inf` if the validation or test set contains characters not seen in the train set
# However, this should not happen for models where you implement smoothing.

# %%
## Please do not change anything in this code block.

unigram_model = UnigramModel(train_text)

# Check the perplexity of the unigram model on the train set
print('unigram train perplexity:',
      unigram_model.get_perplexity(train_text))
# Out:
# unigram train perplexity: 12.237629309435524

# %%
## Please do not change anything in this code block.

eval_ngram_model(model=unigram_model, ngram=1, ds=validation_text, ds_name='validation', eval_prefixes=eval_prefixes, eval_sequences=eval_sequences, num_names=5)
# Out:
# EVALUATION probability distribution is valid: True
# EVALUATION of 1-gram on validation perplexity: inf
# EVALUATION 1-gram generated names are , jmasrppa, , , mhasun
# EVALUATION 1-gram generated names with prefix <s><s>sh are <s><s>shnnkn, <s><s>shtaradiht, <s><s>shferuahjh, <s><s>shamu, <s><s>shsdsim
# EVALUATION 1-gram top most likely chars after <s><s>aa are a, </s>, i, n, h

# %% [markdown]
# ### Smoothing
#
# Implement a smoothed version of the unigram model. You may extend the `UnigramModel` class and re-use some of the functions.  For unigram model, you should implement Add-1 smoothing.
#
# You may refer to the lecture slides or [3.5 Smoothing](https://web.stanford.edu/~jurafsky/slp3/3.pdf) for details on different smoothing technqiues.

# %%
"""
Implementation of unigram model with Add-1 smoothing.

"""
class SmoothedUnigramModel(UnigramModel):

    def __init__(self, train_text):
        super().__init__(train_text)

    # You should override ONLY those functions
    # which calculate probability of a unigram.
    # You can override get_next_char_probabilities
    # or any other helper functions you use in UnigramModel
    # to calculate unigram probabilities.

    # Implement Laplace or Add-1 smoothing for the unigram model

    # ADD YOUR CODE HERE
    # START CODE

    def get_next_char_probabilities(self):
        """
        Return a dictionary of probabilities for each char in the vocabulary using Add-1 smoothing.

        Returns:
            key: char, value: probability
        """
        # Calculate the total number of tokens with smoothing
        total_tokens_smoothed = self.total_tokens + self.vocab_size

        next_char_probabilities = {}
        vocab_set = vocab.get_itos()
        for char in vocab_set:
          next_char_probabilities[char] = (self.unigram_counts.get(char, 0)+1) / total_tokens_smoothed

        return next_char_probabilities
    # END CODE

# %%
## Please do not change anything in this code block.

smoothed_unigram_model = SmoothedUnigramModel(train_text)

# Check the perplexity of the smoothed unigram model on the train set
print('smoothed unigram train perplexity:',
      smoothed_unigram_model.get_perplexity(train_text))
# Out:
# smoothed unigram train perplexity: 12.238762176896088

# %%
## Please do not change anything in this code block.

eval_ngram_model(model=smoothed_unigram_model, ngram=1, ds=validation_text, ds_name='validation', eval_prefixes=eval_prefixes, eval_sequences=eval_sequences,  num_names=5)
# Out:
# EVALUATION probability distribution is valid: True
# EVALUATION of 1-gram on validation perplexity: 19.88390920805442
# EVALUATION 1-gram generated names are rhtiaspm, d, aebeaesh, r, ahdaruah
# EVALUATION 1-gram generated names with prefix <s><s>sh are <s><s>shnhrr, <s><s>sh, <s><s>shds, <s><s>shdamaiyah, <s><s>shtntrbead
# EVALUATION 1-gram top most likely chars after <s><s>aa are a, </s>, i, n, h

# %%
# Release models we don't need any more.
del unigram_model
del smoothed_unigram_model

# %% [markdown]
# ## 1.2 Bigram

# %%
"""
Implementation of a Bigram Model.
"""

class BigramModel(NGramLanguageModel):
    def __init__(self, train_text):
        """
        Initialise and train the model with train_text.

        Args:
            train_text [list of list]: list of tokenised names
        """

        # ADD YOUR CODE HERE
        # START CODE
        super(BigramModel, self).__init__(train_text)
        self.bigram_counts = get_bigram_counts(train_text)
        #print(self.unigram_counts)
        self.total_tokens = sum(sum(inner_dict.values()) for inner_dict in self.bigram_counts.values())
        self.vocab = vocab
        self.vocab_size = vocab_size
        self.k = 0
        unigram_model = UnigramModel(train_text)
        self.unigram_prob = unigram_model.next_char_probabilities
        self.lambda_1, self.lambda_2 = (0,1)
        self.next_char_probabilities = self.get_next_char_probabilities()
        # END CODE

    def get_next_char_probabilities(self):
        """
        Returns a probability distribution over all chars in the vocabulary.
        Probability distribution should sum to one.

        Returns:
            P: dictionary or nested dictionary; Output format depends on n-gram
            Examples:
                for N=2 (bigram); dict[key:bigram_char1, value:dict[key:bigram_char2,value:probability of bigram]]
                    > P["a"]["b"] = 0.0001 (which stands of P("b"|"a"))
        """

        # ADD YOUR CODE HERE
        # START CODE
        next_char_probabilities = {}
        vocab_set = self.vocab.get_itos()
        for char1 in vocab_set:
          temp = {}
          for char2 in vocab_set:
            if char1 in self.bigram_counts:
              temp[char2] = (self.bigram_counts[char1].get(char2, 0)) / sum(self.bigram_counts[char1].values())
            else:
              temp[char2] = 1/self.vocab_size
          next_char_probabilities[char1] = temp
        # END CODE

        return next_char_probabilities


    def get_name_log_probability(self, name):
        """
        Calculates the log probability of name according to the n-gram model.
        Be careful with cases for which probability of the name is zero.

        Args:
            name [list]: list of tokens

        Returns:
            Log probability of the name [float]
        """

        # ADD YOUR CODE HERE
        # START CODE
        name_log_probability = 0.0

        for i in range(len(name)):
          char2 = name[i]
          if i!=0:
            char1 = name[i-1]
          else:
            char1 = '<s>'
          if(char2 == '<s>'):
            continue
          if char1 in self.next_char_probabilities and char2 in self.next_char_probabilities[char1]: #and self.next_char_probabilities[char1][char2]!=0
            probability = self.next_char_probabilities[char1][char2]
          elif char1 in self.next_char_probabilities and char2 not in self.next_char_probabilities[char1]:
            probability = self.next_char_probabilities[char1]["<unk>"]
          elif char1 not in self.next_char_probabilities and char2 in self.next_char_probabilities[char1]:
            probability = self.next_char_probabilities["<unk>"][char2]
          else:
            probability = self.next_char_probabilities["<unk>"]["<unk>"]
          if probability==0:
            return float("-inf")
          name_log_probability += math.log(probability)

        # END CODE

        return name_log_probability


    def get_perplexity(self, text):
        """
        Returns the perplexity of the model on a text as a float.

        Args:
            text [list]: a list of string tokens

        Returns:
            perplexity of the given text [float]
        """

        # ADD YOUR CODE HERE
        # START CODE
        count = 0
        for name in text:
          count += len(name)-1 # Excluding 1st char as its [START]

        total_log_probability = sum(self.get_name_log_probability(name) for name in text)
        avg_log_probability = total_log_probability / count
        perplexity = math.exp(-avg_log_probability)
        # END CODE

        return perplexity


    def generate_names(self, k, n=MAX_NAME_LENGTH, prefix=None):
        """
        Given a prefix, generate k names according to the model.
        The default prefix is None.

        Args:
            k [int]: Number of names to generate
            n [int]: Maximum length (number of tokens) in the generated name
            prefix [list of tokens]: Prefix after which the names have to be generated

        Returns:
            list of generated names [list]
        """

        # ADD YOUR CODE HERE
        # START CODE
        names = []

        if prefix == None:
            prev_char = '<s>'
        else:
            prev_char = prefix[-1]

        for i in range(k):
          if prefix == None:
            temp_name = []
          else:
            temp_name = list(prefix)
          for j in range(n):
            filtered_probabilities = {char: prob for char, prob in self.next_char_probabilities[prev_char].items() if char not in {"<unk>,<s>"}}
            char = random.choices(list(filtered_probabilities.keys()), weights=list(filtered_probabilities.values()))[0]
            if char == '</s>':
              break
            temp_name.append(char)
            prev_char = char
          temp_name = ''.join(temp_name)
          names.append(temp_name)
        # END CODE

        return names


    def get_most_likely_chars(self, sequence, k):
        """
        Given a sequence of characters, outputs k most likely characters after the sequence.

        Args:
            sequence [list[str]]: list of characters
            k [int]: number of most likely characters to return

        Returns:
            chars [list[str]]: *Ordered* list of most likely characters
                        (with charcater at index 0 being the most likely and
                        character at index k-1 being the least likely)

        """
        # ADD YOUR CODE HERE
        # START CODE
        last_char = sequence[-1]
        if last_char not in self.bigram_counts:
          return []
        else:
          sorted_chars = sorted(self.next_char_probabilities[last_char].keys(), key=lambda char: self.next_char_probabilities[last_char][char], reverse=True)
          most_likely_chars = sorted_chars[:k]
        # END CODE

        return most_likely_chars

# %% [markdown]
# ### Eval

# %%
## Please do not change anything in this code block.

bigram_model = BigramModel(train_text)

# check the perplexity of the bigram model on training data
print('bigram train perplexity:',
      bigram_model.get_perplexity(train_text))
# Out:
# bigram train perplexity: 10.130254540832889

# %%
## Please do not change anything in this code block.

eval_ngram_model(model=bigram_model, ngram=2, ds=validation_text, ds_name='validation', eval_prefixes=eval_prefixes, eval_sequences=eval_sequences, num_names=5)
# Out:
# EVALUATION probability distribution is valid: True
# EVALUATION of 2-gram on validation perplexity: inf
# EVALUATION 2-gram generated names are b, ishi, nga, neshilen, iriyarim
# EVALUATION 2-gram generated names with prefix <s><s>sh are <s><s>sha, <s><s>sh, <s><s>sh, <s><s>sh, <s><s>sh
# EVALUATION 2-gram top most likely chars after <s><s>aa are </s>, n, r, m, l

# %% [markdown]
# ### Smoothing
#
# Implement a smoothed version of the bigram model. You may extend the `BigramModel` class and re-use some of the functions.
#
# You will implement the following smoothing techniques:
# -  Laplace or add-k smoothing
# - Interpolation

# %% [markdown]
# **Laplace or Add-k smoothing**
# - what is the effect of changing `k`?

# %%
"""choose your hyperparameter and see the difference in performance"""

# ADD YOUR CODE HERE

# CHANGE THE None VALUES TO YOUR DESIRED VALUES
# Please feel free to play with these hyperparameters to see the effects on the
# quality of generated names and perplexity

BIGRAM_LAPLACE_K = 6 # value of k for add-k or Laplac smoothing in bigram models

# %%
"""
Implementation of a bigram model with laplace or add-k smoothing.

"""

class LaplaceSmoothedBigramModel(BigramModel):
    # This class extends BigramModel.

    def __init__(self, train_text, k):
        super().__init__(train_text)
        self.k = k # specify k for smoothing
        self.next_char_probabilities = self.get_next_char_probabilities()

    # You should override ONLY those functions
    # which calculate probability of a bigram.
    # You can override get_next_char_probabilities
    # or any other helper functions you use in BigramModel
    # to calculate bigram probabilities.

    # ADD YOUR CODE HERE
    # START CODE
    def get_next_char_probabilities(self):
        """
        Returns a probability distribution over all chars in the vocabulary.
        Probability distribution should sum to one.

        Returns:
            P: dictionary or nested dictionary; Output format depends on n-gram
            Examples:
                for N=2 (bigram); dict[key:bigram_char1, value:dict[key:bigram_char2,value:probability of bigram]]
                    > P["a"]["b"] = 0.0001 (which stands of P("b"|"a"))
        """

        # ADD YOUR CODE HERE
        # START CODE
        next_char_probabilities = {}
        vocab_set = self.vocab.get_itos()
        for char1 in vocab_set:
          temp = {}
          for char2 in vocab_set:
            if char1 in self.bigram_counts:
              temp[char2] = (self.bigram_counts[char1].get(char2, 0)+self.k) / (sum(self.bigram_counts[char1].values())+self.k *self.vocab_size )
            else:
              temp[char2] = 1/self.vocab_size
          next_char_probabilities[char1] = temp
        # END CODE

        return next_char_probabilities
    # END CODE

# %%
## Please do not change anything in this code block.

smoothed_bigram_model = LaplaceSmoothedBigramModel(train_text, k=BIGRAM_LAPLACE_K)

# check the perplexity of the bigram model on training data
print('smoothed bigram train perplexity:',
      smoothed_bigram_model.get_perplexity(train_text))
# Out:
# smoothed bigram train perplexity: 10.57632832694931

# %%
## Please do not change anything in this code block.
eval_ngram_model(model=smoothed_bigram_model, ngram=2, ds=validation_text, ds_name='validation', eval_prefixes=eval_prefixes, eval_sequences=eval_sequences, num_names=5)
# Out:
# EVALUATION probability distribution is valid: True
# EVALUATION of 2-gram on validation perplexity: 14.022474170048804
# EVALUATION 2-gram generated names are jamusaki, ttyajaj, an, aleen, janahr
# EVALUATION 2-gram generated names with prefix <s><s>sh are <s><s>shi<s>shummc, <s><s>shhilalan, <s><s>shimsh, <s><s>shta, <s><s>shjhyambsh
# EVALUATION 2-gram top most likely chars after <s><s>aa are </s>, n, r, m, l

# %% [markdown]
# **Interpolation**
# - what are good values for `lambdas` in interpolation?

# %%
"""choose your hyperparameter and see the difference in performance"""

# ADD YOUR CODE HERE

# CHANGE THE None VALUES TO YOUR DESIRED VALUES
# Please feel free to play with these hyperparameters to see the effects on the
# quality of generated names and perplexity

BIGRAM_LAMBDAS = (0.1, 0.9) # lambdas for interpolation smoothing in bigram models

# %%
"""
Implementation of a bigram model with interpolation smoothing
"""

class InterpolationSmoothedBigramModel(BigramModel):

    def __init__(self, train_text, lambdas):
        super().__init__(train_text)
        self.lambda_1, self.lambda_2 = lambdas
        self.k = 2
        unigram_model = UnigramModel(train_text)
        self.unigram_prob = unigram_model.next_char_probabilities
        self.next_char_probabilities = self.get_next_char_probabilities()

    # You should override ONLY those functions
    # which calculate probability of a bigram.
    # You can override get_next_char_probabilities
    # or any other helper functions you use in BigramModel
    # to calculate bigram probabilities.

    # ADD YOUR CODE HERE
    # START CODE
    def get_next_char_probabilities(self):
      """
      Returns a probability distribution over all chars in the vocabulary.
      Probability distribution should sum to one.

      Returns:
          P: dictionary or nested dictionary; Output format depends on n-gram
          Examples:
              for N=2 (bigram); dict[key:bigram_char1, value:dict[key:bigram_char2,value:probability of bigram]]
                  > P["a"]["b"] = 0.0001 (which stands of P("b"|"a"))
      """

      # ADD YOUR CODE HERE
      # START CODE
      next_char_probabilities = {}
      vocab_set = self.vocab.get_itos()
      for char1 in vocab_set:
        temp = {}
        for char2 in vocab_set:
          if char1 in self.bigram_counts:
            temp[char2] = self.lambda_2 * (self.bigram_counts[char1].get(char2, 0)+self.k) / (sum(self.bigram_counts[char1].values()) +self.k *self.vocab_size) + self.lambda_1 * self.unigram_prob[char2]
          else:
            temp[char2] = self.lambda_2 * 1/self.vocab_size + self.lambda_1 * self.unigram_prob[char2]
        next_char_probabilities[char1] = temp
      # END CODE

      return next_char_probabilities

# %%
## Please do not change anything in this code block.

smoothed_bigram_model = InterpolationSmoothedBigramModel(train_text, lambdas=BIGRAM_LAMBDAS)

# check the perplexity of the bigram model on training data
print('smoothed bigram train perplexity:',
      smoothed_bigram_model.get_perplexity(train_text))
# Out:
# smoothed bigram train perplexity: 10.44078691893485

# %%
## Please do not change anything in this code block.

eval_ngram_model(model=smoothed_bigram_model, ngram=2, ds=validation_text, ds_name='validation', eval_prefixes=eval_prefixes, eval_sequences=eval_sequences, num_names=5)
# Out:
# EVALUATION probability distribution is valid: True
# EVALUATION of 2-gram on validation perplexity: 14.859875908954665
# EVALUATION 2-gram generated names are prat, , am, b, anshan
# EVALUATION 2-gram generated names with prefix <s><s>sh are <s><s>shari, <s><s>shl, <s><s>shoj, <s><s>sheeerara, <s><s>shniladasa
# EVALUATION 2-gram top most likely chars after <s><s>aa are </s>, n, r, m, l

# %%
# Release models we don't need any more.
del bigram_model
del smoothed_bigram_model

# %% [markdown]
# ## 1.3 Trigram (smoothed)

# %%
"""choose your hyperparameter and see the difference in performance"""

# ADD YOUR CODE HERE

# CHANGE THE None VALUES TO YOUR DESIRED VALUES
# Please feel free to play with these hyperparameters to see the effects on the
# quality of generated names and perplexity

TRIGRAM_LAMBDAS = (0.1, 0.4, 0.5) # lambdas for interpolation smoothing in trigram models

# %%
"""
Implementaion of a Trigram Model with interpolation smoothing.
"""

class TrigramModel(NGramLanguageModel):
    def __init__(self, train_text):
        """
        Initialise and train the model with train_text.

        Args:
            train_text [list of list]: list of tokenised names
        """

        # ADD YOUR CODE HERE
        # START CODE
        super(TrigramModel, self).__init__(train_text)
        self.trigram_counts = get_trigram_counts(train_text)
        #print(self.unigram_counts)
        #self.total_tokens = sum(sum(inner_dict.values()) for inner_dict in self.trigram_counts.values())
        self.vocab = vocab
        self.vocab_size = vocab_size
        self.k = 2
        self.lambda_1, self.lambda_2, self.lambda_3 = TRIGRAM_LAMBDAS
        bigram_model = BigramModel(train_text)
        unigram_model = UnigramModel(train_text)
        self.bigram_prob = bigram_model.next_char_probabilities
        self.unigram_prob = unigram_model.next_char_probabilities
        self.next_char_probabilities = self.get_next_char_probabilities()
        # END CODE


    def get_next_char_probabilities(self):
        """
        Returns a probability distribution over all chars in the vocabulary.
        Probability distribution should sum to one.

        Returns:
            P: dictionary or nested dictionary; Output format depends on n-gram
            Examples:
                for N=1 (unigram); dict[key:unigram,value:probability of unigram]
                    > P["a"] = 0.0001
                for N=2 (bigram); dict[key:bigram_char1, value:dict[key:bigram_char2,value:probability of bigram]]
                    > P["a"]["b"] = 0.0001 (corresponding to P(b|a))
                for N=3 (trigram); dict[dict[dict]]
                    > P["a"]["b"]["c"] = 0.0001 (corresponding to P(c|ab))
        """

        # ADD YOUR CODE HERE
        # START CODE
        next_char_probabilities = {}
        tot_prob = {}
        vocab_set = self.vocab.get_itos()
        for char1 in vocab_set:
          temp = {}
          tot_temp = {}
          for char2 in vocab_set:
            temp_1 ={}
            tot_temp_1={}
            for char3 in vocab_set:
              if char1  in self.trigram_counts and char2 in self.trigram_counts[char1]:
                temp_1[char3] = (self.trigram_counts[char1][char2].get(char3, 0)+self.k) / (sum(self.trigram_counts[char1][char2].values()) + self.k *self.vocab_size )
                tot_temp_1[char3] = self.lambda_3 *(self.trigram_counts[char1][char2].get(char3, 0)) / (sum(self.trigram_counts[char1][char2].values())) \
                + self.lambda_2*self.bigram_prob[char2][char3] + self.lambda_1* self.unigram_prob[char3]
              else:
                temp_1[char3] = 1/self.vocab_size
                tot_temp_1[char3] = self.lambda_3 * 1/self.vocab_size + self.lambda_2 * self.bigram_prob[char2][char3] + self.lambda_1 * self.unigram_prob[char3]
            temp[char2] = temp_1
            tot_temp[char2] = tot_temp_1
          next_char_probabilities[char1] = temp
          tot_prob[char1] = tot_temp
          self.tot_prob = tot_prob
        # END CODE

        return next_char_probabilities


    def get_name_log_probability(self, name):
        """
        Calculates the log probability of name according to the n-gram model.
        Be careful with cases for which probability of the name is zero.

        Args:
            name [list]: list of tokens

        Returns:
            Log probability of the name [float]
        """

        # ADD YOUR CODE HERE
        # START CODE
        name_log_probability = 0.0

        for i in range(len(name)):
          char3 = name[i]
          if i==0:
            char1 = '<s>'
            char2 = '<s>'
          elif i==1:
            char1 = '<s>'
            char2 = name[i-1]
          else:
            char1 = name[i-2]
            char2 = name[i-1]
          if(char3 == '<s>'):
            continue
          if self.next_char_probabilities[char1][char2][char3]!=0:
            probability = self.lambda_3 * self.next_char_probabilities[char1][char2][char3] + self.lambda_2 * self.bigram_prob[char2][char3] + self.lambda_1 *self.unigram_prob[char3]
            name_log_probability += math.log(probability)

        # END CODE

        return name_log_probability


    def get_perplexity(self, text):
        """
        Returns the perplexity of the model on a text as a float.

        Args:
            text [list]: a list of string tokens

        Returns:
            perplexity of the given text [float]
        """

        # ADD YOUR CODE HERE
        # START CODE
        count = 0
        for name in text:
          count += len(name)

        total_log_probability = sum(self.get_name_log_probability(name) for name in text)
        avg_log_probability = total_log_probability / count #len(text)
        perplexity = math.exp(-avg_log_probability)
        # END CODE

        return perplexity


    def generate_names(self, k, n=MAX_NAME_LENGTH, prefix=None):
        """
        Given a prefix, generate k names according to the model.
        The default prefix is None.

        Args:
            k [int]: Number of names to generate
            n [int]: Maximum length (number of tokens) in the generated name
            prefix [list of tokens]: Prefix after which the names have to be generated

        Returns:
            list of generated names [list]
        """

        # ADD YOUR CODE HERE
        # START CODE
        names = []

        if prefix == None:
          prev_char1 = '<s>'
          prev_char2 = '<s>'
        elif len(prefix)==1:
          prev_char1 = '<s>'
          prev_char2 = prefix[-1]
        else:
          prev_char1 = prefix[-2]
          prev_char2 = prefix[-1]

        for i in range(k):
          if prefix==None:
            temp_name = []
          else:
            temp_name = list(prefix)
          for j in range(n):
            # char = random.choices(list(self.next_char_probabilities[prev_char1][prev_char2].keys()), weights=list(self.next_char_probabilities[prev_char1][prev_char2].values()))[0]
            filtered_probabilities = {char: prob for char, prob in self.tot_prob[prev_char1][prev_char2].items() if char not in {"<unk>","<s>"}}
            char = random.choices(list(filtered_probabilities.keys()), weights=list(filtered_probabilities.values()))[0]
            if char == '</s>':
              break
            temp_name.append(char)
            prev_char1 = prev_char2
            prev_char2 = char
          temp_name = ''.join(temp_name)
          names.append(temp_name)
        # END CODE

        return names


    def get_most_likely_chars(self, sequence, k):
        """
        Given a sequence of characters, outputs k most likely characters after the sequence.

        Args:
            sequence [list[str]]: list of characters
            k [int]: number of most likely characters to return

        Returns:
            chars [list[str]]: *Ordered* list of most likely characters
                        (with charcater at index 0 being the most likely and
                        character at index k-1 being the least likely)

        """
        # ADD YOUR CODE HERE
        # START CODE
        prev_char1 = sequence[-2]
        prev_char2 = sequence[-1]
        if prev_char1 not in self.trigram_counts or prev_char2 not in self.trigram_counts:
          return []
        else:
          # sorted_chars = sorted(self.next_char_probabilities[prev_char1][prev_char2].keys(), key=lambda char: self.next_char_probabilities[prev_char1][prev_char2][char], reverse=True)
          sorted_chars = sorted(self.tot_prob[prev_char1][prev_char2].keys(), key=lambda char: self.tot_prob[prev_char1][prev_char2][char], reverse=True)
          most_likely_chars = sorted_chars[:k]
        # END CODE

        return most_likely_chars

# %% [markdown]
# #### Eval

# %%
## Please do not change anything in this code block.

trigram_model = TrigramModel(train_text)

print('trigram train perplexity:',
      trigram_model.get_perplexity(train_text))
# Out:
# trigram train perplexity: 7.295483113423092

# %%
## Please do not change anything in this code block.

eval_ngram_model(model=trigram_model, ngram=3, ds=validation_text, ds_name='validation', eval_prefixes=eval_prefixes, eval_sequences=eval_sequences, num_names=5)
# Out:
# EVALUATION probability distribution is valid: True
# EVALUATION of 3-gram on validation perplexity: 9.870883180589825
# EVALUATION 3-gram generated names are khukhuma, r, pri, , t
# EVALUATION 3-gram generated names with prefix <s><s>sh are <s><s>sha, <s><s>shsh, <s><s>shr, <s><s>sh, <s><s>sha
# EVALUATION 3-gram top most likely chars after <s><s>aa are n, </s>, s, r, m

# %%
# Release models we don't need any more.
del trigram_model

# %% [markdown]
# # Module 2: Neural Language Modelling

# %% [markdown]
# ## 2.1 Neural N-gram Language Model
#
# For this part of the assignment, you should use the GPU (you can do this by changing the runtime of this notebook).
#
# In this section, you will implement a neural version of an n-gram model.  The model will use a simple feedforward neural network that takes the previous `n-1` chars and outputs a distribution over the next char.
#
# You will use PyTorch to implement the model.  We've provided a little bit of code to help with the data loading using [PyTorch's data loaders](https://pytorch.org/docs/stable/data.html)

# %%
# Import the necessary libraries

import math
import time
import random
import os, sys
import json
from functools import partial

from tqdm import tqdm
import torch
import torch.nn as nn

from matplotlib import pyplot as plt
import numpy as np

# %%
## Please do not change anything in this code block.

def collate_ngram(batch, text_pipeline):
    """
    Converts the text in the batch to tokens
    and maps the tokens to indices in the vocab.
    The text in the batch is a list of ngrams
    i.e. if N=3, then text contains 3 tokens in a list
    and batch is a list of such texts.

    Returns:
        batch_input [pytorch tensor]:
            input for n-gram model with size batch_size*(ngram-1)
        batch_output [pytorch tensor]:
            output for n-gram model with size batch_size
    """

    batch_input, batch_output = [], []

    # Process each text in the batch
    for text in batch:
        token_id_sequence = text_pipeline(text)
        # last token is the output, and
        #  pervious ngram-1 tokens are inputs
        output = token_id_sequence.pop()
        input = token_id_sequence
        batch_input.append(input)
        batch_output.append(output)

    # Convert lists to PyTorch tensors and moves to the gpu (if using)
    batch_input = torch.tensor(batch_input, dtype=torch.long)
    batch_output = torch.tensor(batch_output, dtype=torch.long)
    if USE_CUDA:
        batch_input = batch_input.cuda()
        batch_output = batch_output.cuda()

    return batch_input, batch_output


def get_dataloader(input_text, vocab, ngram, batch_size, shuffle):
    """
    Creates a dataloader for the n-gram model which
    takes in a list of list of tokens, appends the START token
    at the starting of each text, and converts text into ngrams.

    Example: For a trigram model, the list of characters are
        ["n", "a", "v", "r"]
    will be converted into lists
        ["n", "a", "v"], ["a", "v", "r"]

    For each ngram, first ngram-1 tokens are input and last token
    is the output. Each token is converted into a index in the vocab.
    The dataloader generates a batch of input, output pairs as
    pytorch tensors.


    Args:
        input_text [list[list[str]]]: list of list of tokens
        vocab [torchtext.vocab]: vocabulary of the corpus
    """

    ngram_sequences = []
    for text in input_text:
        if text[0] == START:
            text = [START]*(N_GRAM_LENGTH-2) + text
        else:
            text = [START]*(N_GRAM_LENGTH-1) + text

        # Create training pairs for each char in the text
        for idx in range(len(text) - ngram + 1):
            ngram_sequence = text[idx : (idx + ngram)]
            ngram_sequences.append(ngram_sequence)

    text_pipeline = lambda x: vocab(x)
    collate_fn = collate_ngram

    # creates a DataLoader for the dataset

    """
    dataloader documentation
    https://pytorch.org/docs/stable/data.html#torch.utils.data.DataLoader
    """

    dataloader = DataLoader(
        ngram_sequences,
        batch_size=batch_size,
        shuffle=shuffle,
        collate_fn=partial(collate_fn, text_pipeline=text_pipeline),
        )
    return dataloader

# %% [markdown]
# #### FNN Implementation

# %% [markdown]
# **Feed-forward Neural Language Modelling**
#
# Like the n-gram LM, the feedforward neural LM approximates the probability of a char given the entire prior context $P(w_t|w_{1:t−1})$ by approximating based on the $N-1$ previous chars:
# $$P(w_t|w_1,...,w_{t−1}) ≈ P(w_t|w_{t−N+1},...,w_{t−1})$$
#
#
# Implement the FNN LM given in this paper: [Neural Probabilistic Language Model](https://www.jmlr.org/papers/volume3/bengio03a/bengio03a.pdf)
#
# The architecture of the FNN can be described by the equation and figure:
#
# $$y = b + W x + U \text t \text a \text n \text h (d + H x)$$
#
# - $x$ is of size $(ngram-1)*m$ where $m$ is the size embedding dimensions
# - $y$ is of size $V*1$ where $V$ is the vocabulary size
#
# ![FNN_LM](https://drive.google.com/uc?id=1aQhkXjWelHfiBfmBQV3z5TjHFNMtqtzT)
#
#
# **Some tips**:
# - embed the chars with dimension $m$ (example, $60$), then flatten into a single embedding for  $n-1$  chars (with size  $(n-1)*m$ )
# - you can use Adam or Stochastic Gradient Descent (SGD) for optimising the cross entropy loss
# - If you are using SGD, you may want to use momentum, and a learning rate scheduler
# - do early stopping based on validation set loss or perplexity
#
# **Important**: Fix seed as 42 whenever performing any randomized operations, e.g., initializing ML models.

# %%
"""
Implemenation of a PyTorch Module that holds the neural network for your model

"""
class FNN_LM(nn.Module):

    def __init__(self, vocab_size, emb_size, hid_size, ngram):
        super(FNN_LM, self).__init__()
        self.ngram = ngram

        # YOUR CODE HERE
        # START CODE
        self.emb_size = emb_size
        self.embeddings = nn.Embedding(vocab_size, emb_size)

        self.W = nn.Linear((ngram - 1) * emb_size, vocab_size, bias=False)  # Changed bias
        self.U = nn.Linear(hid_size, vocab_size, bias=False)
        self.H = nn.Linear((ngram - 1) * emb_size, hid_size, bias=False)
        self.d = nn.Parameter(torch.zeros(hid_size))
        self.b = nn.Parameter(torch.zeros(vocab_size))
        # END CODE


    def forward(self, chars):
        """
        Args:
            chars: this is a tensor of inputs with shape [batch_size x ngram-1]

        Returns:
            logits: a tensor of log probabilities with shape [batch_size x vocab_size]

        """

        # YOUR CODE HERE
        # START CODE
        embedded = self.embeddings(chars).view(-1, (self.ngram - 1) * self.emb_size)

        hidden = torch.tanh(self.H(embedded) + self.d)
        logits = self.b + self.W(embedded) + self.U(hidden)
        # END CODE

        return logits

# %% [markdown]
# **The following is the Trainer class for the FNN LM. Add your code for the `training` and `validation` loops.**

# %%
class NeuralNGramTrainer:
    """
    NeuralNGramTrainer wraps FNN_LM to handle training and evaluation.

    """

    # NOTE: you are free to add additional inputs/functions
    # to NeuralNGramTrainer to make training better
    # make sure to define and add it within the input
    # and initialization if you are using any additional inputs
    # for usage in the function

    def __init__(
        self,
        ngram,
        model,
        optimizer,
        criterion,
        train_dataloader,
        valid_dataloader,
        epochs,
        use_cuda,
        vocab,
        model_dir
    ):

        self.ngram = ngram
        self.model = model
        self.epochs = epochs
        self.optimizer = optimizer
        self.criterion = criterion
        self.train_dataloader = train_dataloader
        self.valid_dataloader = valid_dataloader
        self.use_cuda = use_cuda
        self.model_dir = model_dir
        self.loss = {"train": [], "val": []}
        self.vocab = vocab

        if self.use_cuda:
          self.device = 'cuda'
        else:
          self.device = 'cpu'

        # Move the model to GPU if available
        if self.use_cuda:
            self.model = self.model.cuda()


    def training(self):
        """
        Trains the model with train_dataloader and validates using valid_dataloader

        """
        # You may change the input arguments to this function,
        # but make sure to also change the code wherever this function is called

        # ADD YOUR CODE HERE
        # FOR TRAINING & VALIDATION
        # START CODE

        for epoch in range(self.epochs):
            self.train(epoch)
            self.validate(epoch)
            print("Epoch: {}/{}, Train Loss={:.3f}, Val Loss={:.3f}".format(epoch + 1,self.epochs,self.loss["train"][-1],self.loss["val"][-1],))


    def train(self, epoch):
        """
        training epoch
        """
        self.model.train()
        loss_in_epoch = []

        for i, batch in enumerate(self.train_dataloader):
            inputs = batch[0].to(self.device)
            output = batch[1].to(self.device)
            pred = self.model(inputs)
            loss = self.criterion(pred, output)
            loss.backward()
            self.optimizer.step()
            self.optimizer.zero_grad()

            loss_in_epoch.append(loss.item())

        mean_loss = np.mean(loss_in_epoch)

        self.loss["train"].append(mean_loss)

    def validate(self, epoch):
        """
        validation epoch
        """
        self.model.eval()
        loss_in_epoch = []

        with torch.no_grad():
            for i, batch in enumerate(self.valid_dataloader):
                inputs = batch[0].to(self.device)
                output = batch[1].to(self.device)

                pred = self.model(inputs)
                loss = self.criterion(pred, output)

                loss_in_epoch.append(loss.item())

        mean_loss = np.mean(loss_in_epoch)

        self.loss["val"].append(mean_loss)

    # END CODE


    def plot_losses(self):
        """
        Plots the training and validation losses
        """
        plt.plot(self.loss['train'], label='train_ppl')
        plt.plot(self.loss['val'], label='val_ppl')
        plt.legend()
        plt.show


    def save_model(self):
        """
        Save final model to directory

        """

        model_path = os.path.join(self.model_dir, "model.pt")
        torch.save(self.model, model_path)


    def save_loss(self):
        """
        Save train/val loss as json file to the directory

        """

        loss_path = os.path.join(self.model_dir, "loss.json")
        with open(loss_path, "w") as fp:
            json.dump(self.loss, fp)


    def get_next_char_probabilities(self):
        """
        Return a dictionary of probabilities for each char in the vocabulary
        with a default starting sequence of [START]*(ngram-1)
        Example:
            If ngram=3, then default starting sequence for which
            probabilities have to be returned is
            [START, START]

        Returns:
            dictionary with key: char, value: probability

        """

        # ADD YOUR CODE HERE
        # START CODE
        starting_sequence_ids = [self.vocab.get_stoi()["<s>"] for i in range(self.ngram - 1)]
        starting_sequence_tensor = torch.tensor(starting_sequence_ids, dtype=torch.long)

        if self.use_cuda:
            starting_sequence_tensor = starting_sequence_tensor.cuda()

        with torch.no_grad():
            logits = self.model(starting_sequence_tensor)
            probabilities = torch.softmax(logits, dim=1).cpu().numpy()[0]

        next_char_probabilities = {char: prob for char, prob in zip(self.vocab.get_itos(), probabilities)}
        # END CODE

        return next_char_probabilities


    def generate_names(self, k, n=8, prefix=None):
        """
        Given a prefix, generate k names according to the model.
        The default prefix is None.

        Args:
            k [int]: Number of names to generate
            n [int]: Maximum length (number of tokens) in the generated name
            prefix [list of tokens]: Prefix after which the names have to be generated

        Returns:
            list of generated names [list[str]]
        """

        # ADD YOUR CODE HERE
        # START CODE
        names = []

        current_sequence = []
        if prefix==None:
          prefix_len = 0
        else:
          prefix_len = len(prefix)
        count = min(prefix_len,self.ngram-1)
        for i in range(self.ngram-1-count):
          current_sequence.append("<s>")
        for i in range(count):
          current_sequence.append(prefix[prefix_len-count+i])

        self.model.eval()
        for _ in range(k):
            if prefix!=None:
              name = list(prefix)
            else:
              name=[]
            curr_seq = list(current_sequence)
            for _ in range(n):
                input_ids = [self.vocab.get_stoi()[char] for char in curr_seq]
                input_tensor = torch.tensor(input_ids, dtype=torch.long)
                # print(input_tensor.shape)

                if self.use_cuda:
                    input_tensor = input_tensor.cuda()

                with torch.no_grad():
                    logits = self.model(input_tensor)
                    next_char_id = torch.multinomial(torch.softmax(logits, dim=1), 1).item()
                    next_char = self.vocab.get_itos()[next_char_id]

                curr_seq.append(next_char)
                curr_seq = curr_seq[1:]

                if next_char == "</s>":
                    break
                if next_char == "<unk>" or next_char == "<s>":
                  continue
                name.append(next_char)

            name = ''.join(name)
            names.append(name)
        # END CODE

        # don't forget self.model.eval()

        return names


    def get_perplexity(self, text):
        """
        Returns the perplexity of the model on text as a float.

        Args:
            text [list[list[str]]]: list of tokenised names
            > Example:
            [['<s>', 'a', 'a', 'b', 'i', 'd', '</s>'],
            ['<s>', 'a', 'a', 'b', 'i', 'd', 'a', '</s>']]

        Returns:
            perplexity [float]

        """

        # ADD YOUR CODE HERE

        # you may want to use the dataloader here
        # don't forget self.model.eval()
        # START CODE
        self.model.eval()
        total_loss = 0.0
        total_tokens = 0
        text_dataloader = get_dataloader(text, vocab, ngram = self.ngram, batch_size=32, shuffle=False)
        log_prob = nn.CrossEntropyLoss(reduction = 'sum')

        for batch_input, batch_output in text_dataloader:
            if self.use_cuda:
                batch_input, batch_output = batch_input.cuda(), batch_output.cuda()

            logits = self.model(batch_input)
            loss = log_prob(logits, batch_output)

            total_loss += loss.item()
            total_tokens += batch_output.numel()

        perplexity = math.exp(total_loss / total_tokens)
        # END CODE

        return perplexity


    def get_most_likely_chars(self, sequence, k):
        """
        Given a sequence of characters, outputs k most likely characters after the sequence.

        Args:
            sequence [list[str]]: list of characters
            k [int]: number of most likely characters to return

        Returns:
            chars [list[str]]: *Ordered* list of most likely characters
                        (with charcater at index 0 being the most likely and
                        character at index k-1 being the least likely)

        """

        # ADD YOUR CODE HERE

        # don't forget self.model.eval()
        # START CODE
        self.model.eval()
        current_sequence = []
        sequence_len = len(sequence)
        count = min(sequence_len,self.ngram-1)
        for i in range(self.ngram-1-count):
          current_sequence.append("<s>")
        for i in range(count):
          current_sequence.append(sequence[sequence_len-count+i])

        input_ids = [self.vocab.get_stoi()[char] for char in current_sequence]
        input_tensor = torch.tensor(input_ids, dtype=torch.long)

        if self.use_cuda:
            input_tensor = input_tensor.cuda()

        with torch.no_grad():
            logits = self.model(input_tensor)
            sorted_probs, sorted_indices = torch.topk(logits, k)
            most_likely_chars = [self.vocab.get_itos()[idx] for idx in sorted_indices.squeeze().tolist()][:k]
        # END CODE

        return most_likely_chars

# %%
"""choose your hyperparameter and see the difference in performance"""

# ADD YOUR CODE HERE

# CHANGE THE None VALUES TO YOUR DESIRED VALUES
# Please feel free to play with these hyperparameters to see the effects on the
# quality of generated names and perplexity

MAX_NAME_LENGTH = 8 # maximum length of name for generation

# Remember to fix seed as 42
torch.manual_seed(42)

# check if GPU is available
USE_CUDA = torch.cuda.is_available()
print(f"GPU is available: {USE_CUDA}")

N_GRAM_LENGTH = 5 # The length of the n-gram (N_GRAM_LENGTH=3 for trigram)
EMB_SIZE = 20 # The size of the embedding
HID_SIZE = 25 # The size of the hidden layer
EPOCHS = 50
BATCH_SIZE = 32
SHUFFLE = False # if dataset should be shuffled
# Out:
# GPU is available: False

# %%
## Please do not change anything in this code block.

# Get data iterator and build vocabulary from input text
train_text, vocab = get_tokenised_text_and_vocab(ds_type='train')
validation_text, _ = get_tokenised_text_and_vocab(ds_type='valid', vocab=vocab)

# Check the size of vocabulary
vocab_size = len(vocab.get_stoi())
print(vocab_size)

# Load training and validation dataloaders
train_dataloader = get_dataloader(train_text, vocab, ngram = N_GRAM_LENGTH, batch_size=BATCH_SIZE, shuffle=SHUFFLE)
valid_dataloader = get_dataloader(validation_text, vocab, ngram = N_GRAM_LENGTH, batch_size=BATCH_SIZE, shuffle=SHUFFLE)
# Out:
# 29

# %%
# ADD YOUR CODE HERE

# This is the part where you should train your FNN_LM model

# CHANGE THE None VALUES TO YOUR DESIRED VALUES

# Initialise the model, optimizer, learning rate scheduler (optional), and loss criteria
model = FNN_LM(vocab_size=vocab_size, emb_size=EMB_SIZE, hid_size=HID_SIZE, ngram=N_GRAM_LENGTH)
# Move the model to GPU if available
if USE_CUDA:
  model = model.cuda()


optimizer = torch.optim.SGD(model.parameters(), lr=0.001)
criterion = nn.CrossEntropyLoss()

# ADD YOUR CODE HERE
# change the directory name with your SAPname and SRno

model_dir = 'SAPname_SRno/fnn'

if not os.path.exists(model_dir):
    os.makedirs(model_dir)

# NOTE: if you are **optionally** using additional options for the trainer
# (e.g., a training scheduler), please add them below.
trainer = NeuralNGramTrainer(
        ngram=N_GRAM_LENGTH,
        model=model,
        optimizer=optimizer,
        criterion=criterion,
        train_dataloader=train_dataloader,
        valid_dataloader=valid_dataloader,
        epochs=EPOCHS,
        use_cuda=USE_CUDA,
        model_dir=model_dir,
        vocab=vocab)

# Train the model
trainer.training()
print("Training finished.")

trainer.save_model()
trainer.save_loss()
vocab_path = os.path.join(model_dir, "vocab.pt")
torch.save(vocab, vocab_path)
print("Model artifacts saved to folder:", model_dir)
# Out:
# Epoch: 1/50, Train Loss=3.187, Val Loss=3.027
# Epoch: 2/50, Train Loss=2.828, Val Loss=2.885
# Epoch: 3/50, Train Loss=2.691, Val Loss=2.811
# Epoch: 4/50, Train Loss=2.610, Val Loss=2.764
# Epoch: 5/50, Train Loss=2.554, Val Loss=2.731
# Epoch: 6/50, Train Loss=2.512, Val Loss=2.708
# Epoch: 7/50, Train Loss=2.479, Val Loss=2.690
# Epoch: 8/50, Train Loss=2.452, Val Loss=2.676
# Epoch: 9/50, Train Loss=2.429, Val Loss=2.665
# Epoch: 10/50, Train Loss=2.410, Val Loss=2.656
# Epoch: 11/50, Train Loss=2.393, Val Loss=2.648
# Epoch: 12/50, Train Loss=2.378, Val Loss=2.642
# Epoch: 13/50, Train Loss=2.365, Val Loss=2.637
# Epoch: 14/50, Train Loss=2.353, Val Loss=2.633
# Epoch: 15/50, Train Loss=2.342, Val Loss=2.629
# Epoch: 16/50, Train Loss=2.332, Val Loss=2.626
# Epoch: 17/50, Train Loss=2.322, Val Loss=2.623
# Epoch: 18/50, Train Loss=2.314, Val Loss=2.620
# Epoch: 19/50, Train Loss=2.306, Val Loss=2.618
# Epoch: 20/50, Train Loss=2.299, Val Loss=2.616
# Epoch: 21/50, Train Loss=2.292, Val Loss=2.615
# Epoch: 22/50, Train Loss=2.285, Val Loss=2.613
# Epoch: 23/50, Train Loss=2.279, Val Loss=2.612
# Epoch: 24/50, Train Loss=2.273, Val Loss=2.611
# Epoch: 25/50, Train Loss=2.268, Val Loss=2.610
# Epoch: 26/50, Train Loss=2.263, Val Loss=2.609
# Epoch: 27/50, Train Loss=2.258, Val Loss=2.608
# Epoch: 28/50, Train Loss=2.253, Val Loss=2.608
# Epoch: 29/50, Train Loss=2.248, Val Loss=2.607
# Epoch: 30/50, Train Loss=2.244, Val Loss=2.607
# Epoch: 31/50, Train Loss=2.240, Val Loss=2.606
# Epoch: 32/50, Train Loss=2.236, Val Loss=2.606
# Epoch: 33/50, Train Loss=2.232, Val Loss=2.606
# Epoch: 34/50, Train Loss=2.228, Val Loss=2.605
# Epoch: 35/50, Train Loss=2.225, Val Loss=2.605
# Epoch: 36/50, Train Loss=2.221, Val Loss=2.605
# Epoch: 37/50, Train Loss=2.218, Val Loss=2.605
# Epoch: 38/50, Train Loss=2.215, Val Loss=2.605
# Epoch: 39/50, Train Loss=2.212, Val Loss=2.605
# Epoch: 40/50, Train Loss=2.209, Val Loss=2.605
# Epoch: 41/50, Train Loss=2.206, Val Loss=2.605
# Epoch: 42/50, Train Loss=2.203, Val Loss=2.605
# Epoch: 43/50, Train Loss=2.200, Val Loss=2.605
# Epoch: 44/50, Train Loss=2.197, Val Loss=2.605
# Epoch: 45/50, Train Loss=2.195, Val Loss=2.605
# Epoch: 46/50, Train Loss=2.192, Val Loss=2.605
# Epoch: 47/50, Train Loss=2.190, Val Loss=2.605
# Epoch: 48/50, Train Loss=2.187, Val Loss=2.606
# Epoch: 49/50, Train Loss=2.185, Val Loss=2.606
# Epoch: 50/50, Train Loss=2.183, Val Loss=2.606
# Training finished.
# Model artifacts saved to folder: SAPname_SRno/fnn

# %% [markdown]
# ### Eval

# %%
eval_ngram_model(trainer, ngram=N_GRAM_LENGTH, ds=validation_text, ds_name='valid', eval_prefixes=eval_prefixes, eval_sequences=eval_sequences, num_names=5, is_neural=True)
# Out:
# EVALUATION probability distribution is valid: True
# EVALUATION of 5-gram on valid perplexity: 13.54382019939278
# EVALUATION 5-gram generated names are shareei, mahehd, sikarsha, shin, srar
# EVALUATION 5-gram generated names with prefix <s><s>sh are <s><s>shutamenar, <s><s>shribhar, <s><s>shkesai, <s><s>shee, <s><s>shesa
# EVALUATION 5-gram top most likely chars after <s><s>aa are s, n, r, m, l

# %% [markdown]
# Load your saved model and generate a few names

# %%
START = "<s>"   # Start-of-name token
END = "</s>"    # End-of-name token
UNK = "<unk>"   # token representing out of unknown (or out of vocabulary) tokens

# ADD YOUR CODE HERE
# change the directory name with your SAPname and SRno

folder = 'SAPname_SRno/fnn'
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# load the saved model
model = torch.load(f"{folder}/model.pt", map_location=device)
vocab = torch.load(f"{folder}/vocab.pt")

# NOTE: if you are **optionally** using additional options for the trainer
# (e.g., a training scheduler), please add them below.
trainer = NeuralNGramTrainer(
        ngram=N_GRAM_LENGTH,
        model=model,
        optimizer=None,
        criterion=None,
        train_dataloader=None,
        valid_dataloader=None,
        epochs=None,
        use_cuda=USE_CUDA,
        model_dir=None,
        vocab=vocab)

# Generate a few names
names = trainer.generate_names(k=5, n=MAX_NAME_LENGTH, prefix=['a','a','s','h'])
print(", ".join(names))

# you may use this block to test if your model and vocab load properly,
# and that your functions are able to generate sentences, calculate perplexity etc.
# Out:
# aash, aashana, aashum, aashi, aashar

# %%
# Release models we don't need any more.
del trainer
del model

# %% [markdown]
# ## 2.2 Recurrent Neural Networks for Language Modelling

# %% [markdown]
# For this stage of the assignment, you will implement an RNN language model.
#
# Some tips:
# * use dropout
# * use the same weights for the embedding layer and the pre-softmax layer
# * train with Adam

# %%
"""
Implemenation of a PyTorch Module that holds the RNN

"""
class RNN_LM(nn.Module):

    # you may change the input arguments for __init__
    def __init__(self,vocab_size, emb_size):
        super(RNN_LM, self).__init__()

        # YOUR CODE HERE
        # START CODE
        self.emb_size = emb_size
        # self.hid_size = hid_size
        self.embedding = nn.Embedding(vocab_size, self.emb_size)
        #self.rnn = nn.RNN(self.emb_size, self.emb_size, num_layers = 2, dropout=0.2, batch_first=True)
        self.rnn = nn.LSTM(self.emb_size, self.emb_size, num_layers = 2, dropout=0.2, batch_first=True)
        self.dropout = nn.Dropout(0.2)
        self.fc = nn.Linear(self.emb_size, vocab_size)
        self.fc.weight = self.embedding.weight
        # END CODE

    def forward(self,chars):

        # YOUR CODE HERE
        # START CODE
        embedded = self.embedding(chars)
        rnn_output, hidden = self.rnn(embedded)
        #print(rnn_output.shape)
        if len(rnn_output.shape) == 2:
          rnn_output = rnn_output.unsqueeze(0)
        #print(rnn_output.shape)
        rnn_output = rnn_output[:, -1, :]

        rnn_output = self.dropout(rnn_output)
        logits = self.fc(rnn_output)
        # END CODE

        return logits

# %%
class RNNTrainer:
    """
    RNNTrainer wraps RNN_LM to handle training and evaluation.

    """

    # NOTE: you are free to add additional inputs/functions
    # to RNNTrainer to make training better
    # make sure to define and add it within the input
    # and initialization if you are using any additional inputs
    # for usage in the function

    def __init__(
        self,
        model,
        optimizer,
        criterion,
        train_dataloader,
        valid_dataloader,
        epochs,
        use_cuda,
        vocab,
        model_dir
    ):

        self.model = model
        self.epochs = epochs
        self.optimizer = optimizer
        self.criterion = criterion
        self.train_dataloader = train_dataloader
        self.valid_dataloader = valid_dataloader
        self.use_cuda = use_cuda
        self.model_dir = model_dir
        self.loss = {"train": [], "val": []}
        self.vocab = vocab

        if self.use_cuda:
          self.device = 'cuda'
        else:
          self.device = 'cpu'

        # Move the model to GPU if available
        if self.use_cuda:
            self.model = self.model.cuda()

        self.min_loss = -1

    def training(self):
        """
        Trains the model with train_dataloader and validates using valid_dataloader

        """
        # You may change the input arguments to this function,
        # but make sure to also change the code wherever this function is called

        # ADD YOUR CODE HERE FOR TRAINING & VALIDATION
        # START CODE

        for epoch in range(self.epochs):
            self.train(epoch)
            self.validate(epoch)
            print("Epoch: {}/{}, Train Loss={:.3f}, Val Loss={:.3f}".format(epoch + 1,self.epochs,self.loss["train"][-1],self.loss["val"][-1],))


    def train(self, epoch):
        """
        training epoch
        """
        self.model.train()
        loss_in_epoch = []

        for i, batch in enumerate(self.train_dataloader):
            inputs = batch[0].to(self.device)
            output = batch[1].to(self.device)
            pred = self.model(inputs)
            loss = self.criterion(pred, output)
            loss.backward()
            self.optimizer.step()
            self.optimizer.zero_grad()

            loss_in_epoch.append(loss.item())

        mean_loss = np.mean(loss_in_epoch)

        self.loss["train"].append(mean_loss)

    def validate(self, epoch):
        """
        validation epoch
        """
        self.model.eval()
        loss_in_epoch = []

        with torch.no_grad():
            for i, batch in enumerate(self.valid_dataloader):
                inputs = batch[0].to(self.device)
                output = batch[1].to(self.device)

                pred = self.model(inputs)
                loss = self.criterion(pred, output)

                loss_in_epoch.append(loss.item())

        mean_loss = np.mean(loss_in_epoch)
        if(self.min_loss == -1 or self.min_loss>mean_loss):
          self.min_loss = mean_loss
          self.save_best()

        self.loss["val"].append(mean_loss)

    # END CODE



    def save_model(self):
        """
        Save final model to directory

        """

        model_path = os.path.join(self.model_dir, "model.pt")
        torch.save(self.model, model_path)

    def save_best(self):
        """
        Save final model to directory

        """

        model_path = os.path.join(self.model_dir, "model_bst.pt")
        torch.save(self.model, model_path)


    def save_loss(self):
        """
        Save train/val loss as json file to the directory

        """

        loss_path = os.path.join(self.model_dir, "loss.json")
        with open(loss_path, "w") as fp:
            json.dump(self.loss, fp)


    def get_next_char_probabilities(self):
        """
        Return a dictionary of probabilities for each char in the vocabulary
        with a default starting sequence of [START]

        Returns:
            dictionary with key: char, value: probability

        """

        # ADD YOUR CODE HERE
        # START CODE
        #starting_sequence_ids = [self.vocab.get_stoi()["<s>"] for i in range(self.ngram - 1)]
        starting_sequence_ids = [self.vocab.get_stoi()["<s>"]]
        starting_sequence_tensor = torch.tensor(starting_sequence_ids, dtype=torch.long)

        if self.use_cuda:
            starting_sequence_tensor = starting_sequence_tensor.cuda()

        with torch.no_grad():
            logits = self.model(starting_sequence_tensor)
            probabilities = torch.softmax(logits, dim=1).cpu().numpy()[0]

        next_char_probabilities = {char: prob for char, prob in zip(self.vocab.get_itos(), probabilities)}
        # END CODE

        return next_char_probabilities


    def generate_names(self, k, n, prefix=None):
        """
        Given a prefix, generate k names according to the model.
        The default prefix is None.

        Args:
            k [int]: Number of names to generate
            n [int]: Maximum length (number of tokens) in the generated name
            prefix [list of tokens]: Prefix after which the names have to be generated

        Returns:
            list of generated names [list[str]]
        """

        # ADD YOUR CODE HERE
        # START CODE
        names = []

        self.model.eval()
        for _ in range(k):
            if prefix!=None:
              name = list(prefix)
              if prefix[0]!="<s>":
                curr_seq = ["<s>"] + list(prefix)
              else:
                curr_seq = list(prefix)
            else:
              name=[]
              curr_seq = ["<s>"]
            for _ in range(n):
                input_ids = [self.vocab.get_stoi()[char] for char in curr_seq]
                input_tensor = torch.tensor(input_ids, dtype=torch.long)
                # print(input_tensor.shape)

                if self.use_cuda:
                    input_tensor = input_tensor.cuda()

                with torch.no_grad():
                    logits = self.model(input_tensor)
                    next_char_id = torch.multinomial(torch.softmax(logits, dim=1), 1).item()
                    next_char = self.vocab.get_itos()[next_char_id]

                curr_seq.append(next_char)
                # curr_seq = curr_seq[1:]

                if next_char == "</s>":
                    break
                if next_char == "<s>" or next_char == "<unk>":
                  continue
                name.append(next_char)

            name = ''.join(name)
            names.append(name)
        # END CODE

        # don't forget self.model.eval()

        return names


    def get_perplexity(self, text):
        """
        Returns the perplexity of the model on text as a float.

        Args:
            text [list[list[str]]]: list of tokenised names
            > Example:
            [['<s>', 'a', 'a', 'b', 'i', 'd', '</s>'],
            ['<s>', 'a', 'a', 'b', 'i', 'd', 'a', '</s>']]

        Returns:
            perplexity [float]

        """

        # ADD YOUR CODE HERE

        # you may want to use the dataloader here
        # don't forget self.model.eval()
        # START CODE
        self.model.eval()
        total_loss = 0.0
        total_tokens = 0
        text_dataloader = get_dataloader(text, vocab, ngram = 10, batch_size=32, shuffle=False)
        for names in text:
          total_tokens += len(names)

        for batch_input, batch_output in text_dataloader:
            if self.use_cuda:
                batch_input, batch_output = batch_input.cuda(), batch_output.cuda()

            logits = self.model(batch_input)
            log_prob = nn.CrossEntropyLoss(reduction = 'sum')
            loss = log_prob(logits, batch_output)
            # loss = self.criterion(logits, batch_output)

            total_loss += loss.item()
            #total_tokens += batch_output.numel()

        perplexity = math.exp(total_loss / total_tokens)
        # END CODE

        return perplexity


    def get_most_likely_chars(self, sequence, k):
        """
        Given a sequence of characters, outputs k most likely characters after the sequence.

        Args:
            sequence [list[str]]: list of characters
            k [int]: number of most likely characters to return

        Returns:
            chars [list[str]]: *Ordered* list of most likely characters
                        (with charcater at index 0 being the most likely and
                        character at index k-1 being the least likely)

        """

        # ADD YOUR CODE HERE

        # don't forget self.model.eval()
        # START CODE
        self.model.eval()
        current_sequence = []

        if len(sequence) == 0:
          current_sequence.append("<s>")
        else:
          current_sequence = list(sequence)

        input_ids = [self.vocab.get_stoi()[char] for char in current_sequence]
        input_tensor = torch.tensor(input_ids, dtype=torch.long)

        if self.use_cuda:
            input_tensor = input_tensor.cuda()

        with torch.no_grad():
            logits = self.model(input_tensor)
            sorted_probs, sorted_indices = torch.topk(logits, k)
            most_likely_chars = [self.vocab.get_itos()[idx] for idx in sorted_indices.squeeze().tolist()][:k]
        # END CODE

        return most_likely_chars

# %%
"""choose your hyperparameter and see the difference in performance"""

# ADD YOUR CODE HERE

# CHANGE THE None VALUES TO YOUR DESIRED VALUES
# Please feel free to play with these hyperparameters to see the effects on the
# quality of generated names and perplexity

MAX_NAME_LENGTH = 8 # maximum length of name for generation

# Remember to fix seed as 42
torch.manual_seed(42)

# check if GPU is available
USE_CUDA = torch.cuda.is_available()
print(f"GPU is available: {USE_CUDA}")

EPOCHS = 10
BATCH_SIZE = 32
SHUFFLE = False # if dataset should be shuffled
EMB_SIZE = 45 # The size of the embedding
N_GRAM_LENGTH = 10 # Used in dataloader

# Get data iterator and build vocabulary from input text
train_text, vocab = get_tokenised_text_and_vocab(ds_type='train')
validation_text, _ = get_tokenised_text_and_vocab(ds_type='valid', vocab=vocab)

# Check the size of vocabulary
vocab_size = len(vocab.get_stoi())
print(vocab_size)

# create the dataloaders for training and validation

# ADD YOUR CODE HERE
train_dataloader = get_dataloader(train_text, vocab, ngram = N_GRAM_LENGTH, batch_size=BATCH_SIZE, shuffle=SHUFFLE)
valid_dataloader = get_dataloader(validation_text, vocab, ngram = N_GRAM_LENGTH, batch_size=BATCH_SIZE, shuffle=SHUFFLE)
# Out:
# GPU is available: False
# 29

# %%
# ADD YOUR CODE HERE

# CHANGE THE None VALUES TO YOUR DESIRED VALUES

# Initialize the model
# you may want to pass arguments to RNN_LM based on your implementation
model = RNN_LM(vocab_size=vocab_size, emb_size=EMB_SIZE)
# Move the model to GPU if available
if USE_CUDA:
  model = model.cuda()

# Initialise the optimizer, learning rate scheduler (optional), and loss criteria
optimizer = torch.optim.Adam(model.parameters(), lr=0.0001)
#optimizer = torch.optim.SGD(model.parameters(), lr=0.005)
criterion = nn.CrossEntropyLoss()

# ADD YOUR CODE HERE
# change the directory name with your SAPname and SRno

model_dir = 'SAPname_SRno/rnn'

if not os.path.exists(model_dir):
    os.makedirs(model_dir)

# NOTE: if you are **optionally** using additional options for the trainer
# (e.g., a training scheduler), please add them below.
trainer = RNNTrainer(
        model=model,
        optimizer=optimizer,
        criterion=criterion,
        train_dataloader=train_dataloader,
        valid_dataloader=valid_dataloader,
        epochs=EPOCHS,
        use_cuda=USE_CUDA,
        vocab=vocab,
        model_dir=model_dir
        )

# Train the model
trainer.training()
print("Training finished.")

trainer.save_model()
trainer.save_loss()
vocab_path = os.path.join(model_dir, "vocab.pt")
torch.save(vocab, vocab_path)
print("Model artifacts saved to folder:", model_dir)
# Out:
# Epoch: 1/10, Train Loss=2.895, Val Loss=2.828
# Epoch: 2/10, Train Loss=2.661, Val Loss=2.747
# Epoch: 3/10, Train Loss=2.558, Val Loss=2.676
# Epoch: 4/10, Train Loss=2.478, Val Loss=2.619
# Epoch: 5/10, Train Loss=2.404, Val Loss=2.594
# Epoch: 6/10, Train Loss=2.338, Val Loss=2.584
# Epoch: 7/10, Train Loss=2.282, Val Loss=2.579
# Epoch: 8/10, Train Loss=2.235, Val Loss=2.564
# Epoch: 9/10, Train Loss=2.204, Val Loss=2.560
# Epoch: 10/10, Train Loss=2.175, Val Loss=2.558
# Training finished.
# Model artifacts saved to folder: SAPname_SRno/rnn

# %% [markdown]
# ### Eval

# %%
## Please do not change anything in this code block.

def eval_rnn_model(model, ds, ds_name, eval_prefixes, eval_sequences, num_names=5):
    """
    Runs the following evaluations on n-gram models:
    (1) checks if probability distribution returned by model.get_next_char_probabilities() sums to one
    (2) checks the perplexity of the model
    (3) generates names using model.generate_names()
    (4) generates names given a prefix using model.generate_names()
    (4) output most likely characters after a given sequence of chars using model.get_most_likely_chars()
    """

    # (1) checks if probability distributions sum to one
    is_valid = check_validity(model, 1, True)
    print(f'EVALUATION probability distribution is valid: {is_valid}')

    # (2) evaluate the perplexity of the model on the dataset
    print(f'EVALUATION of RNN on {ds_name} perplexity:',
        model.get_perplexity(ds))

    # (3) generate a few names
    generated_names = ", ".join(model.generate_names(k=num_names, n=MAX_NAME_LENGTH))
    print(f'EVALUATION RNN generated names are {generated_names}')

    # (4) generate a few names given a prefix
    for prefix in eval_prefixes:
        generated_names_with_prefix = ", ".join(model.generate_names(k=num_names, n=MAX_NAME_LENGTH, prefix=prefix))
        prefix = ''.join(prefix)
        print(f'EVALUATION RNN generated names with prefix {prefix} are {generated_names_with_prefix}')

    # (5) get most likely characters after a sequence
    for sequence in eval_sequences:
        most_likely_chars = ", ".join(model.get_most_likely_chars(sequence=sequence, k=num_names))
        sequence = "".join(sequence)
        print(f"EVALUATION RNN the top most likely chars after {sequence} are {most_likely_chars}")

# %%
eval_rnn_model(trainer, ds=validation_text, ds_name='valid', eval_prefixes=eval_prefixes, eval_sequences=eval_sequences, num_names=5)
# Out:
# EVALUATION probability distribution is valid: True
# EVALUATION of RNN on valid perplexity: 9.539280989455007
# EVALUATION RNN generated names are klch, baesh, grimdan, esa, jis
# EVALUATION RNN generated names with prefix <s><s>sh are <s><s>shindey, <s><s>shi, <s><s>shi, <s><s>shkaram, <s><s>sham
# EVALUATION RNN the top most likely chars after <s><s>aa are n, s, r, m, l

# %%
START = "<s>"   # Start-of-name token
END = "</s>"    # End-of-name token
UNK = "<unk>"   # token representing out of unknown (or out of vocabulary) tokens

# ADD YOUR CODE HERE
# change the directory name with your SAPname and SRno

folder = 'SAPname_SRno/rnn'
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# load the saved model
model = torch.load(f"{folder}/model.pt", map_location=device)
vocab = torch.load(f"{folder}/vocab.pt")

# NOTE: if you are **optionally** using additional options for the trainer
# (e.g., a training scheduler), please add them below.
trainer = RNNTrainer(
        model=model,
        optimizer=None,
        criterion=None,
        train_dataloader=None,
        valid_dataloader=None,
        epochs=None,
        use_cuda=USE_CUDA,
        model_dir=None,
        vocab=vocab)

# Generate a few names
names = trainer.generate_names(k=5, n=MAX_NAME_LENGTH, prefix=['a','a','s','h'])
print(", ".join(names))

# you may use this block to test if your model and vocab load properly,
# and that your functions are able to generate sentences, calculate perplexity etc.
# Out:
# aashaddi, aash, aashora, aashy, aash

# %%
# Release models we don't need any more.
del trainer
del model

# %% [markdown]
# # Congratulations!
#
# You've reacehd the end of the assignment. Hope this was a pleasant and fun exercise!
#
# Check the submission instructions mentioned at the begining of the notebook in order to submit your homework.
